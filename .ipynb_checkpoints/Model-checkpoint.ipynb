# %%
ticker = "AAPL"

# %%
from yfinance_data import get_yf_package

  # ou o que quiseres
data = get_yf_package(ticker)

df = data["history"]
info = data["info"]
recs = data["recs_summary"]
charts = data["charts"]

df.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-11-13 00:00:00-05:00  274.109985  276.700012  272.089996  272.950012
# 2025-11-14 00:00:00-05:00  271.049988  275.959991  269.600006  272.410004
# 2025-11-17 00:00:00-05:00  268.820007  270.489990  265.730011  267.459991
# 2025-11-18 00:00:00-05:00  269.989990  270.709991  265.320007  267.440002
# 2025-11-19 00:00:00-05:00  265.529999  272.209991  265.500000  268.559998
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-11-13 00:00:00-05:00  49602800        0.0           0.0
# 2025-11-14 00:00:00-05:00  47431300        0.0           0.0
# 2025-11-17 00:00:00-05:00  45018300        0.0           0.0
# 2025-11-18 00:00:00-05:00  45677300        0.0           0.0
# 2025-11-19 00:00:00-05:00  40355600        0.0           0.0
